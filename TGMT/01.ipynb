# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\hello\anaconda3\lib\site-packages (10.3.0)

# %%
# Shift + Enter : Vua run + them 1 dong moi
# Crtl + Enter : Chi run

# %%
#Them Thu Vien
from PIL import Image

# %%
dir = 'C:/Users/hello/Documents/img'

# %%
image_path = dir + "/01.JPG"
print(image_path)
# Out:
# C:/Users/hello/Documents/img/01.JPG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x203>

# %%
print("Dinh dang anh : ", img01.format)
# Out:
# Dinh dang anh :  JPEG

# %%
print("Kich co anh : ", img01.size)
# Out:
# Kich co anh :  (300, 203)

# %%
new_img_01_path = dir + "/new_01.JPG"
new_img_PNG_01_path = dir + "/new_01.PNG"
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)

# %%
img01.close()
