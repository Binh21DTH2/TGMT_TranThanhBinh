# %%
#Them Thu Vien
from PIL import Image
from imgtools import *

# %%
dir = 'C:/Users/hello/Documents/img'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (300, 203)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x203>
# (177, 285)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=177x285>
# (190, 266)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=190x266>
# (165, 305)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=165x305>
# (189, 266)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=189x266>
# (300, 203)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x203>
# (300, 203)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x203>
