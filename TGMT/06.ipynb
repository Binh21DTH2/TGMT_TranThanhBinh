# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/hello/Documents/img/01.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x203>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=300x203>

# %%
red_band, yellow_band, blue_band = img.split()
display(red_band)
display(yellow_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=300x203>
# <PIL.Image.Image image mode=L size=300x203>
# <PIL.Image.Image image mode=L size=300x203>

# %%
merged_image =  Image.merge("RGB", (red_band, yellow_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x203>
